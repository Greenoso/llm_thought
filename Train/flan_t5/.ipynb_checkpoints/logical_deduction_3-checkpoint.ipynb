# %%
import json
import os
import sys
from typing import Dict, List

import numpy as np
from datasets import load_dataset
from transformers import AutoTokenizer, pipeline
from transformers import T5Tokenizer, T5ForConditionalGeneration

import trlx
from trlx.data.configs import (
    ModelConfig,
    OptimizerConfig,
    SchedulerConfig,
    TokenizerConfig,
    TrainConfig,
    TRLConfig,
)
from trlx.models.modeling_ppo import PPOConfig



### get reward from 

def get_positive_score(scores):
    "Extract value associated with a positive sentiment from pipeline's output"
    return dict(map(lambda x: tuple(x.values()), scores))["POSITIVE"]


default_config = TRLConfig(
    train=TrainConfig(
        seq_length=1024,
        epochs=4,
        total_steps=6000,
        batch_size=12,
        checkpoint_interval=95,
        eval_interval=20,
        pipeline="PromptPipeline",
        trainer="AcceleratePPOTrainer",
        save_best=False,
        tracker="wandb",
        checkpoint_dir='/root/autodl-tmp/msc_ml/t5_large_checkpoints'
    ),
    model=ModelConfig(
        model_path="/root/autodl-tmp/flan-t5-large",
        num_layers_unfrozen=-1,
        model_arch_type="seq2seq",
    ),
    tokenizer=TokenizerConfig(
        tokenizer_path="/root/autodl-tmp/flan-t5-large",
        padding_side="right",
        truncation_side="right",
    ),
    optimizer=OptimizerConfig(
        name="adamw",
        kwargs={
            "lr": 1.0e-4,
            "betas": [0.9, 0.999],
            "eps": 1.0e-8,
            "weight_decay": 1.0e-6,
        },
    ),
    scheduler=SchedulerConfig(
        name="cosine_annealing",
        kwargs={
            "T_max": 100000,
            "eta_min": 5.0e-5,
        },
    ),
    method=PPOConfig(
        name="PPOConfig",
        ### reduce rollouts due to small dataset
        num_rollouts=64,
        chunk_size=12,
        ppo_epochs=4,
        init_kl_coef=0.05,
        target=6,
        horizon=1000,
        gamma=0.99,
        lam=0.95,
        cliprange=0.2,
        cliprange_value=0.2,
        vf_coef=1,
        scale_reward=None,
        ref_mean=None,
        ref_std=None,
        cliprange_reward=10,
        gen_kwargs={
            "max_new_tokens": 100,
            "do_sample": False,
            "top_k": 50,
            "top_p": 0.95,
            "eos_token_id": -1,
            "temperature": 1.0,
        },
    ),
)


def main(hparams={}):
    config = TRLConfig.update(default_config, hparams)


    
    #########################################b
    
    ### reward_se
    def reward_se( prompts: List[str], outputs: List[str], **kwargs) -> List[float]:

        rewards = []
        for q, a in zip(prompts, outputs):
            feedback_prompt = f'Is the answer to the question correct? The question is: {q}. The answer is: {a}'
            feedback = se_generator(feedback_prompt)[0]['generated_text']  # Assuming 'model' is your trained T5 model
            feedback = feedback.lower().strip()
            print(feedback)
            reward = 1.0 if feedback == 'yes' else 0.0

            rewards.append(reward)
        return rewards
    
    
    
    
    
    ### metric_se

    
    def metric_se(samples: List[str], prompts: List[str], outputs: List[str]) -> Dict[str, List[float]]:
        match=[]
        
        for i,prompt in enumerate(prompts):

            index = prompt_all_new.index(prompt)
            if outputs[i].lower().strip()==answer_all[index].lower().strip():
                is_correct=1.0
            else:
                is_correct=0.0
                
            match.append(is_correct)

        return {"Answer Matching": match}
    
    ###########################################e
    
    
    
    ############################b
    # Load the model
    model_se = T5ForConditionalGeneration.from_pretrained("/root/autodl-tmp/flan-t5-large")

    # Load the tokenizer
    tokenizer_se = T5Tokenizer.from_pretrained("/root/autodl-tmp/flan-t5-large")

    # Create the pipeline
    se_generator = pipeline("text2text-generation", model=model_se, tokenizer=tokenizer_se,
        top_k=50,
        truncation=True,
        batch_size=256,
        device=0 if int(os.environ.get("LOCAL_RANK", 0)) == 0 else -1,)
    #############################e


    






    
    #########################b

    ds = load_dataset("json", data_files="/root/autodl-tmp/BIG-Bench-Hard/bbh/navigate.json",field="examples")['train']
    ds_split=ds.train_test_split(test_size=0.2)
    prompt_all=ds['input']
    prompt_all_new= [prompt.replace('\n', ' ') for prompt in prompt_all]
    answer_all=ds['target']
    prompt_train=ds_split['train']['input']
    prompt_train=[]
    prompt_test=ds_split['test']['input']
    prompt_train
    

    ##########################e


    trlx.train(
        prompts=prompt_train,
        eval_prompts=prompt_test,
        reward_fn=reward_se,
        metric_fn=metric_se,
        config=config,
    )

    

    
    
if __name__ == "__main__":
    hparams = {} if len(sys.argv) == 1 else json.loads(sys.argv[1])
    main(hparams)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:201                                                                                  │
# │                                                                                                  │
# │   198                                                                                            │
# │   199                                                                                            │
# │   200 if __name__ == "__main__":                                                                 │
# │ ❱ 201 │   hparams = {} if len(sys.argv) == 1 else json.loads(sys.argv[1])                        │
# │   202 │   main(hparams)                                                                          │
# │   203                                                                                            │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/json/__init__.py:357 in loads                                     │
# │                                                                                                  │
# │   354 │   if (cls is None and object_hook is None and                                            │
# │   355 │   │   │   parse_int is None and parse_float is None and                                  │
# │   356 │   │   │   parse_constant is None and object_pairs_hook is None and not kw):              │
# │ ❱ 357 │   │   return _default_decoder.decode(s)                                                  │
# │   358 │   if cls is None:                                                                        │
# │   359 │   │   cls = JSONDecoder                                                                  │
# │   360 │   if object_hook is not None:                                                            │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/json/decoder.py:337 in decode                                     │
# │                                                                                                  │
# │   334 │   │   containing a JSON document).                                                       │
# │   335 │   │                                                                                      │
# │   336 │   │   """                                                                                │
# │ ❱ 337 │   │   obj, end = self.raw_decode(s, idx=_w(s, 0).end())                                  │
# │   338 │   │   end = _w(s, end).end()                                                             │
# │   339 │   │   if end != len(s):                                                                  │
# │   340 │   │   │   raise JSONDecodeError("Extra data", s, end)                                    │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/json/decoder.py:355 in raw_decode                                 │
# │                                                                                                  │
# │   352 │   │   try:                                                                               │
# │   353 │   │   │   obj, end = self.scan_once(s, idx)                                              │
# │   354 │   │   except StopIteration as err:                                                       │
# │ ❱ 355 │   │   │   raise JSONDecodeError("Expecting value", s, err.value) from None               │
# │   356 │   │   return obj, end                                                                    │
# │   357                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
def reward_se( prompts: List[str], outputs: List[str]) -> List[float]:
    rewards = []
    for q, a in zip(prompts, outputs):
        feedback_prompt = f'Is the answer to the question correct? The question is: {q}. The answer is: {a}'
        feedback = se_generator(feedback_prompt)[0]['generated_text']  # Assuming 'model' is your trained T5 model
        feedback = feedback.lower().strip()
        print(feedback)
        reward = 1.0 if 'yes' in feedback else 0.0
        
        rewards.append(reward)
    return rewards

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration, pipeline
    
    # Load the model
model_se_0 = T5ForConditionalGeneration.from_pretrained("/root/autodl-tmp/flan-t5-large")

    # Load the tokenizer
tokenizer_se = T5Tokenizer.from_pretrained("/root/autodl-tmp/flan-t5-large")

    # Create the pipeline
se_generator= pipeline("text2text-generation", model=model_se_0, tokenizer=tokenizer_se,
                        do_sample= True,
                        top_k= 50,
                        top_p= 0.95,
                        max_length=100,
                        eos_token_id= -1,
                        temperature= 1.0,

                          device=0 if int(os.environ.get("LOCAL_RANK", 0)) == 0 else -1,)



"""    
    # Load the model
model_se_1 = T5ForConditionalGeneration.from_pretrained("/root/autodl-tmp/msc_ml/t5_large_checkpoints/checkpoint_94")

    # Create the pipeline
se_generator_1 = pipeline("text2text-generation", model=model_se_1, tokenizer=tokenizer_se,

        device=0 if int(os.environ.get("LOCAL_RANK", 0)) == 0 else -1,)
"""
# Out:
# '    \n    # Load the model\nmodel_se_1 = T5ForConditionalGeneration.from_pretrained("/root/autodl-tmp/msc_ml/t5_large_checkpoints/checkpoint_94")\n\n    # Create the pipeline\nse_generator_1 = pipeline("text2text-generation", model=model_se_1, tokenizer=tokenizer_se,\n\n        device=0 if int(os.environ.get("LOCAL_RANK", 0)) == 0 else -1,)\n'

# %%
ds = load_dataset("json", data_files="/root/autodl-tmp/BIG-Bench-Hard/bbh/navigate.json",field="examples")['train']
ds_split=ds.train_test_split(test_size=0.2)
prompt_all=ds['input']
prompt_all_new= [prompt.replace('\n', ' ') for prompt in prompt_all]
answer_all=ds['target']
prompt_train=ds_split['train']['input']
prompt_test=ds_split['test']['input']
answer_test=ds_split['test']['target']
answer_train=ds_split['train']['target']



prompt_test_new= ['[{}] Let’ s think step by step.'.format(prompt.replace('\n', ' ')) for prompt in prompt_test]
prompt_train_new= ['[{}] Let’ s think step by step.'.format(prompt.replace('\n', ' ')) for prompt in prompt_train]
    

    
    

def accuracy(prompts: List[str], outputs: List[str]) -> Dict[str, List[float]]:
    match=[]
        
    for i,prompt in enumerate(prompts):

        index = prompt_all_new.index(prompt)
        if outputs[i].lower().strip()==answer_all[index].lower().strip():
            is_correct=1.0
        else:
            is_correct=0.0
                
        match.append(is_correct)

    return sum(match)/len(match)
# Out:
# Found cached dataset json (/root/.cache/huggingface/datasets/json/default-e5badb54ef3cd267/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
outputs_0=[]

for i in range(len(prompt_test_new)):
    
    question=prompt_test_new[i]
    answer=answer_test[i]
    print('££££££££££££££££££££££££££',question)
    generation=se_generator(question)[0]['generated_text']
    outputs_0.append(generation)
    print('$$$$$$$$$$$$$',generation)
    print('============',answer)
    print(reward_se(prompts=[question], outputs=[generation]))
# Out:
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Take 9 steps. Turn left. Turn left. Take 9 steps. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ A starting point is the set of directions given to you. The answer: Yes...... to. turn. turn. take. 9 steps. So the answer is Yes.. turn. turn. take.. turn. turn. take. 9 steps.. turn. turn. turn. take. 9 steps.. turn. turn. take. 9 steps. So the answer is Yes.. turn. turn.
# ============ Yes
# no...... turn. turn. take. 9 steps.. turn. turn. take. 9 steps. turn. turn. take. 9 steps. turn. turn. take. 9 steps. turn. turn. take. 9 steps. turn. turn. take. 9 steps. turn. turn. take. 9 steps. turn. turn. take. 9 steps. turn. turn. take. 9 steps.. turn.
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Take 5 steps. Take 5 steps. Take 7 steps. Take 10 steps. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ Once the number of steps increases, the number of steps becomes 2x + 5x + 7x + 10x = 5x + 7. The number of steps is 7x. The number of steps is 7x. The answer: No. by step. back by step. by step. by step. by step. by step. by step. by step. by step. It's just that simple. The answer: Yes.
# ============ No
# no. by step. step by step. by step. by step. step by step. by step. by step. by step. by step.. is just that simple.. is just that simple.. is just that simple.. is just that simple.. is just that simple... is just that simple.. is just that simple.. is just that simple.. is just that simple.
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Take 7 steps. Turn around. Take 7 steps. Turn left. Turn around. Turn around. Turn left. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ No, you do not. You only return to the starting point if you walk around and turn left at the end. The answer: Yes... left .. turn around. Turn around.. turn left . Take 7 steps.. turn around. Turn around. take 7 steps. take 7 steps, turn around. turn around. Turn around. turn left. So, the answer is Yes.. . Take 7 steps.
# ============ Yes
# no.........., - - - - - - - - - - - - - - - - - - - - - - - - - -., - - - - - - - - - - -
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Always face forward. Take 1 step backward. Take 1 step backward. Take 1 step backward. Take 3 steps forward. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ If you go to the starting point, you can start your own scenario. The answer: No. Forward. Backward. Take 3 steps forward. Forward. Backward. Take 1 step backward. take 1 step backward. take 1 step forward. take 3 steps forward. So, the answer is Yes. Forward. Backward. take 1 step forward. Take 1 step backward. take 3 steps forward. Backward. take 1 step back
# ============ Yes
# yes. is a form of transport. is a form of human nature. is a form of transportation. – so, the answer is yes... take 1 step backward. take 3 steps forward.. take 1 step backward. take 3 steps forward. forward. take 1 step backward. take 3 steps forward. is a form of transport. is a form of human nature.
# [1.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Always face forward. Take 5 steps left. Take 1 step backward. Take 4 steps right. Take 1 step backward. Take 8 steps left. Take 6 steps left. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ If you always face forward, you will always take the first step. If you always face backward, you will always take the first step backward. If you always face forward, you will always take the 5th step backward. If you always face right, you will always take the 4th step right. If you always face left, you will always take the 5th step left. If you always face forward, you will always take the 3rd step left. If you
# ============ No
# no — no.. — no.. sa, no. — no... no. — no.. sa, no.. sa, no.. sa, no.. sa, no. sa, no.. sa, no.. sa, no.. sa, no.. sa, no..
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Take 2 steps. Take 10 steps. Take 8 steps. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ If you take 10 steps, the direction of the journey is perpendicular to the road. So the answer is take 10 steps.. = 2 steps. The shortest route is 8 steps. So the answer is take 8 steps. = 2 steps. The shortest way is 2 steps. So the answer is take 2 steps.. The shortest way is 2 steps. = 2 steps. The shortest way is 2 steps. The starting point is
# ============ No
# no.. is the starting point which is not the starting point. the starting point is nowhere in the first place. the starting point is on the path and you cannot go back to it. so the answer is yes... and is located on the path. can be found on the direction of the journey. is the starting point. can be found on the path is located in the direction of the journey. the starting point
# [1.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Turn left. Take 4 steps. Turn around. Take 4 steps. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ If you take 4 steps back then you are going back to the starting point. So the answer is Yes. You turn around and take 4 steps. is the same as turn and right oh turn. So the answer is Yes.. is a type of direction. So the answer is Yes... is a type of direction. is a street crossing. So the answer is Yes.. is a type of
# ============ Yes
# no crossing crossing. crossing. crossing. connecting point. connecting point. crossing. crossing. is a street crossing. is a street intersecting. so the answer is yes... is a type of crossing. crossing. is a street crossing. crossing. is a street intersecting. so the answer is no. crossing. is a street intersecting. is a street passing. is a
# [1.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Always face forward. Take 10 steps left. Take 4 steps forward. Take 1 step left. Take 4 steps backward. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ You always face forward. This requires that you always be facing forward. If you always face away, you will be facing backwards. If you always face forward, you will always be facing forward. So, the answer is No.. face forward. face forward. face forward. face left. face right. face upward. face downward. face forward. face upward. face backward. face backward. face forward. face backward. face right. face
# ============ No
# no n1: face backward. face forward. face left. face right. face upward. face downward. face forward. face upward. face left. face right. face backward. face right. face up. face down. face left. face forward. face right. face forward. face right. face up. face backward. n2: face left. face right. face upward. face downward. face forward. face backward. face left.
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Take 6 steps. Turn left. Take 6 steps. Turn around. Take 2 steps. Take 10 steps. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ The instructions require you to turn right. Turning left results in taking 6 steps. If you are walking in the direction of the left arrow, you first turn left. If you turn right, you will take 2 steps. If you turn back, you will take 10 steps. So the answer is No. direction. right. back. left. right. back. the direction you are walking in. So the answer is No. right.
# ============ No
# no... path.. path. , right. so the answer is no... path............. so the answer is no............ so the answer is no.......
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Take 7 steps. Take 7 steps. Take 10 steps. Take 1 step. Turn left. Take 7 steps. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ You could only take 7 steps in one direction at a time. To go one direction from where you started to where you are now, you need to return to that direction. So the answer is No.. = 2 = 3. = 1 = 2. to go right you need to take 1 step. In the beginning, you are in front of the beginning, so take 7 steps. So the answer is yes. = 2. to go right you need to take 7 steps
# ============ No
# no is the opposite term for right. is the opposite of right. obviously it's wrong to say the opposite. if you take one step to go left then you take the same step to go right. so the answer is no. is the opposite of right. is the opposite of left. is the opposite of left. can be either right or left. so the answer is no... is the opposite of left. can
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Always face forward. Take 9 steps left. Take 4 steps backward. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ To go backward, the steps have to be taken in the same direction. The correct order is Always face forward. So the answer is No.... = [4]. = [1]. a = 1. move = 2 = 4. walk = 5. bring = 6. take = 7. get = 8. come = 9. take = 10. take = 11. go = 12. bring = 13. come = 14. bring = 15. go = 16. take = 18. bring = 19. bring =
# ============ No
# no. is square. so the answer is no. is squat. is square. is square. if the answer were to be any of the above, then it would not be a question of fact, but rather one of the logical properties of a word. so the answer is no. is square. is squat. csi is square. a. is square. c
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Always face forward. Take 10 steps backward. Take 8 steps backward. Take 10 steps forward. Take 7 steps backward. Take 1 step forward. Take 7 steps right. Take 1 step left. Take 1 step right. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ You do not return to the starting point by taking more steps backward, you return to the starting point by taking one step forward. You also cannot return to the starting point by taking 7 steps backward. To take 10 steps forward, you first need to take 10 steps forward and then take 10 steps forward. So, the answer is Yes. forward. 8 steps backward. to take 10 steps forward. to take 10 steps forward. to take 8 steps backward. to
# ============ No
# no., is a very specific meaning for a phrase. in this context, the meaning has to be understood within the context of the question and also the context in which it is intended to be used. so, the answer is yes.......................
# [1.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Turn right. Take 5 steps. Take 6 steps. Take 4 steps. Take 1 step. Turn around. Take 6 steps. Take 10 steps. Turn around. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ In the first two instructions, the right is going to turn, and in the third one the left is going to turn around and the time of return is the same. So, the answer is Yes... = turn right. c. go to next, turn around, take 10 steps, turn around. = next, turn around, take 10 steps. q. to q, turn right. So, the answer is Yes.. q
# ============ Yes
# yes.. equilibria equilibria. this property is defined by the graefes dictionary of english as the property of the form of the verb: the verb. there are two forms of a phrase with a property. and equilibria. the former has a prefix which means to move a corresponding place. the former has a
# [1.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Always face forward. Take 4 steps forward. Take 5 steps right. Take 7 steps left. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ Take 4 steps forward and keep facing forward. Take 5 steps right and keep face right. Take 7 steps left and keep face left. So the answer is Yes. by step. forward. straight ahead. left. and face right. forward and keep facing to the left. in direction the road in going. and face left and continue to the right and then back to the road with straight path. so the answer is Yes. forward and keep face to the right
# ============ No
# no.. right. and.. . . so the answer is no........................... so the answer is no. no... sid.. sid.. sid.. si
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Take 4 steps. Take 2 steps. Take 7 steps. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ If you follow the 4 steps, you are returning to the starting point. Then taking 2 steps is 2 steps. Then taking 7 steps is 7 steps. So, the answer is Yes. 4 steps takes 4 steps. 2 steps takes 2 steps. take 7 steps. 4 steps takes 2 steps. The answer: Take 4. 2 steps is 2 steps. 3 steps is 2 steps. 4 steps is 2 steps. The answer: Take 4. 2 steps
# ============ No
# no. - like - like - like or like - like is the same as an - like - like or like thing. - like - like - like is a piece.. like a person. - like - like - like is a tree. - like - like - like is a man. tree - like - like - like is
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Take 6 steps. Take 10 steps. Take 10 steps. Take 1 step. Take 7 steps. Take 5 steps. Turn around. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ You take 6 steps and 5 steps back to the starting point. The answer: Yes.. and back. and back. = Take 6 steps and a 5 step back. The answer: Yes. and back. and back. and back. = Take 7 steps and a 5 step back. The answer: Take 7. The answer: Take 7 steps and a 5 step back. The answer: Take 7 steps and a 5 step back. The
# ============ No
# no has no definition or., as defined by the acl, can not be used. is not included in the acl. is not listed in the acl. is not included in the acl. cannot be used to describe other classes of property. cannot be used to describe other property classes. yes does not exist. cannot be used to describe other class(es). yes. cannot be used to describe other class(
# [1.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Always face forward. Take 4 steps backward. Take 8 steps forward. Take 10 steps backward. Take 2 steps forward. Take 4 steps forward. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ At the first step of the series, the sequence ends with the last step taken forward. Each sequence ends with the second sequence taken backward. Taking 8 steps forward is the same sequence as taking 8 steps forward, so you can take 8 steps forward from the start until you get to the next step. The sequence ends with the last step taken forward. Thus, the answer is Yes..... = 4 steps forward.. = 4 steps forward.
# ============ Yes
# no - a chain-stitching method of reversing direction in a time series.-stitching gives the best-fit-knee-tie effect (non-stitching).-stitching and herring-stitching can be used in combination with herring-stitching. the effect of these techniques can be used with almost any step
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Take 10 steps. Take 7 steps. Turn around. Take 8 steps. Take 9 steps. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ Take 10 steps to return to the starting point. Take 7 steps to turn around. Take 8 steps to return to the starting point. Take 9 steps to return to the starting point. So, the answer is No. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step.
# ============ Yes
# yess the correct statement. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by step by step. by
# [1.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Always face forward. Take 8 steps right. Take 5 steps forward. Take 10 steps forward. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ To face forward, you take 8 steps right, take 5 steps forward, and take 10 steps forward. The answer: No... = face forward.. face forward = Take 8 steps right. take 8 steps forward. take 5 steps forward. take 5 steps forward. take 10 steps forward. The answer: Yes.. face forward. face forward = take 8 steps right. take 8 steps right. take 5 steps forward. take 5 steps forward. take
# ============ No
# no the answer and repeat it. the answer and repeat it. the answer and repeat it. the answer and repeat it. the answer and repeat it. the answer and repeat it. the answer and repeat it. the answer and repeat it. the answer and repeat it. the answer and repeat it. the answer and repeat it. the answer and repeat it. the answer and repeat it. the answer and repeat it.
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Turn left. Turn right. Turn around. Turn left. Take 4 steps. Turn left. Turn around. Take 3 steps. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ Turn right. Go back to the starting point.. Turning right is a left turn. Turn around is a right turn. So, the answer is No.... TURN RIGHT .. TURN ABOUT .. TURN LEFT. Turn around is a right turn. Turn around is a left turn. Take 3 steps. So, the answer is Yes... TURN RIGHT
# ============ No
# no... -->. ((cstcfjk)*|soc]). (sctcfjk)*(soc). --> cstcfjk (soc) --> cstcfjk (soc) --> *. ((sasm --> cst
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Take 10 steps. Turn around. Take 4 steps. Take 6 steps. Turn around. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ You need to turn around in order to get back to the starting point. The answer: Yes..... (Take 4 steps. Turn around). The answer: Yes.. (Take 4 steps). Turn around. the other option, take 4 steps, turn around. So, the answer is Yes.. The answer: take 4 steps. Turn around.. The answer: take 4. Turn around.. The answer: take
# ============ Yes
# take 4 steps. turn around. take 4 steps. turn around. reynolds take 4 steps. turn around. take reynolds take 4 steps. turn around. reynolds pirate ship take reynolds ship take 4 steps. turn around. take reynolds pirate ship take 4 steps. turn around. take reynolds pirate ship take 4 steps
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Always face forward. Take 3 steps left. Take 10 steps right. Take 7 steps left. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ For every step that goes left, the way back to the starting point is. So the answer is Yes. forward. left. right.. left. The starting point is facing forward, which means the way back is always facing the start point. forward. You always take the next step. You always take the first step from the start point. The starting point is always facing forward, which means the way back is always facing the end point. The starting point is
# ============ Yes
# yes. is facing forward, which means the way back is always facing the start point. is facing forward. the starting point is facing forward, which means the way back is always facing the start point. is facing forward. is facing right. the starting point is facing forward, which means the way back is always facing the starting point. is facing left. the starting point is facing forward, which means
# [1.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Always face forward. Take 8 steps left. Take 9 steps left. Take 8 steps right. Take 8 steps left. Take 3 steps right. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ Let' s say you follow the above instructions to take 3 steps right. It takes 3 steps right to finish taking 8 steps left. As you can see from the second question the answer is no. to go back to the beginning point. So, the answer is no. is to go back to the starting point and take 8 steps left. 8 steps left is to take 8 steps right. The answer is yes. is to go back to the starting point and take
# ============ No
# no is incorrect in the second question. is correct in the second question. cannot be taken after 8 steps left. the other instructions to take 3 steps right in the first question are wrong. the answer is no. is to take 8 steps right. cannot be taken after 8 steps left. the other instructions to take 9 steps left in the first question are wrong. can not be taken after 8 steps left. take 8 steps left. take 3 steps
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Always face forward. Take 7 steps backward. Take 4 steps left. Take 7 steps left. Take 7 steps right. Take 8 steps forward. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ A person always facing forward takes forward steps first. You take 7 steps backward to go to the starting point. If you take 7 steps to go left, you'll be able to walk forward 4 steps. If you take 7 steps to go left, you'll be able to walk right 7 steps. If you take 7 steps right, you'll be able to walk right 7 steps. If you take 4 steps to go left, you'll be able
# ============ No
# no. for the equation.. is the same as the first equation, is a third term. so, the answer is no. is the same as the third term. has two sides. . so if you take four steps left, you are able to take four steps forward. so the answer is no.. is the same as the first equation, is a third term. so, the answer is yes..
# [1.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Always face forward. Take 6 steps right. Take 1 step forward. Take 10 steps left. Take 8 steps forward. Take 9 steps backward. Take 4 steps right. Options: - Yes - No] Let’ s think step by step.
# $$$$$$$$$$$$$ To bring yourself back, you must always face forward. There are no steps backward. Therefore, the answer is No.. = -. = backward. = -. . -. -. - -. = Back. Therefore, the answer is No.. = backward. -. - -. = -. - -. -. -. = Back. Therefore
# ============ Yes
# the answer is no. =. = . =.. =, . = -. = -. -.. -. -. -. -. = . -. -. -. -. -. -. -. -. -. -. - -. -. -. - -
# [0.0]
# ££££££££££££££££££££££££££ [If you follow these instructions, do you return to the starting point? Always face forward. Take 1 step right. Take 3 steps left. Take 2 steps right. Options: - Yes - No] Let’ s think step by step.
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:8                                                                                    │
# │                                                                                                  │
# │    5 │   question=prompt_test_new[i]                                                             │
# │    6 │   answer=answer_test[i]                                                                   │
# │    7 │   print('££££££££££££££££££££££££££',question)                                            │
# │ ❱  8 │   generation=se_generator(question)[0]['generated_text']                                  │
# │    9 │   outputs_0.append(generation)                                                            │
# │   10 │   print('$$$$$$$$$$$$$',generation)                                                       │
# │   11 │   print('============',answer)                                                            │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/transformers/pipelines/text2text_generation.py:165  │
# │ in __call__                                                                                      │
# │                                                                                                  │
# │   162 │   │   │     ids of the generated text.                                                   │
# │   163 │   │   """                                                                                │
# │   164 │   │                                                                                      │
# │ ❱ 165 │   │   result = super().__call__(*args, **kwargs)                                         │
# │   166 │   │   if (                                                                               │
# │   167 │   │   │   isinstance(args[0], list)                                                      │
# │   168 │   │   │   and all(isinstance(el, str) for el in args[0])                                 │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/transformers/pipelines/base.py:1109 in __call__     │
# │                                                                                                  │
# │   1106 │   │   │   │   )                                                                         │
# │   1107 │   │   │   )                                                                             │
# │   1108 │   │   else:                                                                             │
# │ ❱ 1109 │   │   │   return self.run_single(inputs, preprocess_params, forward_params, postproces  │
# │   1110 │                                                                                         │
# │   1111 │   def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):   │
# │   1112 │   │   return [self.run_single(item, preprocess_params, forward_params, postprocess_par  │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/transformers/pipelines/base.py:1116 in run_single   │
# │                                                                                                  │
# │   1113 │                                                                                         │
# │   1114 │   def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):  │
# │   1115 │   │   model_inputs = self.preprocess(inputs, **preprocess_params)                       │
# │ ❱ 1116 │   │   model_outputs = self.forward(model_inputs, **forward_params)                      │
# │   1117 │   │   outputs = self.postprocess(model_outputs, **postprocess_params)                   │
# │   1118 │   │   return outputs                                                                    │
# │   1119                                                                                           │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/transformers/pipelines/base.py:1015 in forward      │
# │                                                                                                  │
# │   1012 │   │   │   │   inference_context = self.get_inference_context()                          │
# │   1013 │   │   │   │   with inference_context():                                                 │
# │   1014 │   │   │   │   │   model_inputs = self._ensure_tensor_on_device(model_inputs, device=se  │
# │ ❱ 1015 │   │   │   │   │   model_outputs = self._forward(model_inputs, **forward_params)         │
# │   1016 │   │   │   │   │   model_outputs = self._ensure_tensor_on_device(model_outputs, device=  │
# │   1017 │   │   │   else:                                                                         │
# │   1018 │   │   │   │   raise ValueError(f"Framework {self.framework} is not supported")          │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/transformers/pipelines/text2text_generation.py:187  │
# │ in _forward                                                                                      │
# │                                                                                                  │
# │   184 │   │   generate_kwargs["min_length"] = generate_kwargs.get("min_length", self.model.con   │
# │   185 │   │   generate_kwargs["max_length"] = generate_kwargs.get("max_length", self.model.con   │
# │   186 │   │   self.check_inputs(input_length, generate_kwargs["min_length"], generate_kwargs["   │
# │ ❱ 187 │   │   output_ids = self.model.generate(**model_inputs, **generate_kwargs)                │
# │   188 │   │   out_b = output_ids.shape[0]                                                        │
# │   189 │   │   if self.framework == "pt":                                                         │
# │   190 │   │   │   output_ids = output_ids.reshape(in_b, out_b // in_b, *output_ids.shape[1:])    │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/torch/utils/_contextlib.py:115 in decorate_context  │
# │                                                                                                  │
# │   112 │   @functools.wraps(func)                                                                 │
# │   113 │   def decorate_context(*args, **kwargs):                                                 │
# │   114 │   │   with ctx_factory():                                                                │
# │ ❱ 115 │   │   │   return func(*args, **kwargs)                                                   │
# │   116 │                                                                                          │
# │   117 │   return decorate_context                                                                │
# │   118                                                                                            │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/transformers/generation/utils.py:1485 in generate   │
# │                                                                                                  │
# │   1482 │   │   │   )                                                                             │
# │   1483 │   │   │                                                                                 │
# │   1484 │   │   │   # 13. run sample                                                              │
# │ ❱ 1485 │   │   │   return self.sample(                                                           │
# │   1486 │   │   │   │   input_ids,                                                                │
# │   1487 │   │   │   │   logits_processor=logits_processor,                                        │
# │   1488 │   │   │   │   logits_warper=logits_warper,                                              │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/transformers/generation/utils.py:2524 in sample     │
# │                                                                                                  │
# │   2521 │   │   │   model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)  │
# │   2522 │   │   │                                                                                 │
# │   2523 │   │   │   # forward pass to get next token                                              │
# │ ❱ 2524 │   │   │   outputs = self(                                                               │
# │   2525 │   │   │   │   **model_inputs,                                                           │
# │   2526 │   │   │   │   return_dict=True,                                                         │
# │   2527 │   │   │   │   output_attentions=output_attentions,                                      │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1501 in _call_impl       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.py:1716 in       │
# │ forward                                                                                          │
# │                                                                                                  │
# │   1713 │   │   │   │   decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_de  │
# │   1714 │   │                                                                                     │
# │   1715 │   │   # Decode                                                                          │
# │ ❱ 1716 │   │   decoder_outputs = self.decoder(                                                   │
# │   1717 │   │   │   input_ids=decoder_input_ids,                                                  │
# │   1718 │   │   │   attention_mask=decoder_attention_mask,                                        │
# │   1719 │   │   │   inputs_embeds=decoder_inputs_embeds,                                          │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1501 in _call_impl       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.py:1086 in       │
# │ forward                                                                                          │
# │                                                                                                  │
# │   1083 │   │   │   │   │   None,  # past_key_value is always None with gradient checkpointing    │
# │   1084 │   │   │   │   )                                                                         │
# │   1085 │   │   │   else:                                                                         │
# │ ❱ 1086 │   │   │   │   layer_outputs = layer_module(                                             │
# │   1087 │   │   │   │   │   hidden_states,                                                        │
# │   1088 │   │   │   │   │   attention_mask=extended_attention_mask,                               │
# │   1089 │   │   │   │   │   position_bias=position_bias,                                          │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1501 in _call_impl       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.py:753 in        │
# │ forward                                                                                          │
# │                                                                                                  │
# │    750 │   │   │   attention_outputs = attention_outputs + cross_attention_outputs[2:]           │
# │    751 │   │                                                                                     │
# │    752 │   │   # Apply Feed Forward layer                                                        │
# │ ❱  753 │   │   hidden_states = self.layer[-1](hidden_states)                                     │
# │    754 │   │                                                                                     │
# │    755 │   │   # clamp inf values to enable fp16 training                                        │
# │    756 │   │   if hidden_states.dtype == torch.float16:                                          │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1501 in _call_impl       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.py:342 in        │
# │ forward                                                                                          │
# │                                                                                                  │
# │    339 │   │   self.dropout = nn.Dropout(config.dropout_rate)                                    │
# │    340 │                                                                                         │
# │    341 │   def forward(self, hidden_states):                                                     │
# │ ❱  342 │   │   forwarded_states = self.layer_norm(hidden_states)                                 │
# │    343 │   │   forwarded_states = self.DenseReluDense(forwarded_states)                          │
# │    344 │   │   hidden_states = hidden_states + self.dropout(forwarded_states)                    │
# │    345 │   │   return hidden_states                                                              │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1501 in _call_impl       │
# │                                                                                                  │
# │   1498 │   │   if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks   │
# │   1499 │   │   │   │   or _global_backward_pre_hooks or _global_backward_hooks                   │
# │   1500 │   │   │   │   or _global_forward_hooks or _global_forward_pre_hooks):                   │
# │ ❱ 1501 │   │   │   return forward_call(*args, **kwargs)                                          │
# │   1502 │   │   # Do not call functions when jit is used                                          │
# │   1503 │   │   full_backward_hooks, non_full_backward_hooks = [], []                             │
# │   1504 │   │   backward_pre_hooks = []                                                           │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/site-packages/transformers/models/t5/modeling_t5.py:253 in        │
# │ forward                                                                                          │
# │                                                                                                  │
# │    250 │   │   # w/o mean and there is no bias. Additionally we want to make sure that the accu  │
# │    251 │   │   # half-precision inputs is done in fp32                                           │
# │    252 │   │                                                                                     │
# │ ❱  253 │   │   variance = hidden_states.to(torch.float32).pow(2).mean(-1, keepdim=True)          │
# │    254 │   │   hidden_states = hidden_states * torch.rsqrt(variance + self.variance_epsilon)     │
# │    255 │   │                                                                                     │
# │    256 │   │   # convert into half-precision if necessary                                        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt

# %%
import torch

# Your code that uses CUDA memory

# Empty the CUDA memory
torch.cuda.empty_cache()

# %%
outputs_0=[]
for i in range(len(prompt_train)):
    
    question=prompt_train[i]
    answer=answer_train[i]
    #print('££££££££££££££££££££££££££',question)
    generation=se_generator_0(question)[0]['generated_text']
    outputs_0.append(generation)
    #print('$$$$$$$$$$$$$',generation)
    #print('============',answer)
    #print(reward_fn(prompts=[question], outputs=[generation]))
    
outputs_1=[]
for i in range(len(prompt_train)):
    
    question=prompt_train[i]
    answer=answer_train[i]
    #print('££££££££££££££££££££££££££',question)
    generation=se_generator_1(question)[0]['generated_text']
    outputs_1.append(generation)
    #print('$$$$$$$$$$$$$',generation)
    #print('============',answer)
    #print(reward_fn(prompts=[question], outputs=[generation]))
    
accuracy_0=accuracy(prompt_train_new,outputs_0)
print(accuracy_0)
accuracy_1=accuracy(prompt_train_new,outputs_1)
print(accuracy_1)

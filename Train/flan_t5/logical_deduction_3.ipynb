# %%
import json
import os
import sys
from typing import Dict, List

import numpy as np
from datasets import load_dataset
from transformers import AutoTokenizer, pipeline
from transformers import T5Tokenizer, T5ForConditionalGeneration

import trlx
from trlx.data.configs import (
    ModelConfig,
    OptimizerConfig,
    SchedulerConfig,
    TokenizerConfig,
    TrainConfig,
    TRLConfig,
)
from trlx.models.modeling_ppo import PPOConfig



### get reward from 

def get_positive_score(scores):
    "Extract value associated with a positive sentiment from pipeline's output"
    return dict(map(lambda x: tuple(x.values()), scores))["POSITIVE"]


default_config = TRLConfig(
    train=TrainConfig(
        seq_length=1024,
        epochs=4,
        total_steps=6000,
        batch_size=12,
        checkpoint_interval=95,
        eval_interval=20,
        pipeline="PromptPipeline",
        trainer="AcceleratePPOTrainer",
        save_best=False,
        tracker="wandb",
        checkpoint_dir='/root/autodl-tmp/msc_ml/t5_large_checkpoints'
    ),
    model=ModelConfig(
        model_path="/root/autodl-tmp/flan-t5-large",
        num_layers_unfrozen=-1,
        model_arch_type="seq2seq",
    ),
    tokenizer=TokenizerConfig(
        tokenizer_path="/root/autodl-tmp/flan-t5-large",
        padding_side="right",
        truncation_side="right",
    ),
    optimizer=OptimizerConfig(
        name="adamw",
        kwargs={
            "lr": 1.0e-4,
            "betas": [0.9, 0.999],
            "eps": 1.0e-8,
            "weight_decay": 1.0e-6,
        },
    ),
    scheduler=SchedulerConfig(
        name="cosine_annealing",
        kwargs={
            "T_max": 100000,
            "eta_min": 5.0e-5,
        },
    ),
    method=PPOConfig(
        name="PPOConfig",
        ### reduce rollouts due to small dataset
        num_rollouts=64,
        chunk_size=12,
        ppo_epochs=4,
        init_kl_coef=0.05,
        target=6,
        horizon=1000,
        gamma=0.99,
        lam=0.95,
        cliprange=0.2,
        cliprange_value=0.2,
        vf_coef=1,
        scale_reward=None,
        ref_mean=None,
        ref_std=None,
        cliprange_reward=10,
        gen_kwargs={
            "max_new_tokens": 256,
            "do_sample": False,
            "top_k": 50,
            "top_p": 0.95,
            "eos_token_id": -1,
            "temperature": 1.0,
        },
    ),
)


def main(hparams={}):
    config = TRLConfig.update(default_config, hparams)


    
    #########################################b
    
    ### reward_se
    def reward_se( prompts: List[str], outputs: List[str], **kwargs) -> List[float]:

        rewards = []
        for q, a in zip(prompts, outputs):
            feedback_prompt = f'Is the answer to the question correct? The question is: {q}. The answer is: {a}'
            feedback = se_generator(feedback_prompt)[0]['generated_text']  # Assuming 'model' is your trained T5 model
            feedback = feedback.lower().strip()
            print(feedback)
            reward = 1.0 if feedback == 'yes' else 0.0

            rewards.append(reward)
        return rewards
    
    
    
    
    
    ### metric_se

    
    def metric_se(samples: List[str], prompts: List[str], outputs: List[str]) -> Dict[str, List[float]]:
        match=[]
        
        for i,prompt in enumerate(prompts):

            index = prompt_all_new.index(prompt)
            if outputs[i].lower().strip()==answer_all[index].lower().strip():
                is_correct=1.0
            else:
                is_correct=0.0
                
            match.append(is_correct)

        return {"Answer Matching": match}
    
    ###########################################e
    
    
    
    ############################b
    # Load the model
    model_se = T5ForConditionalGeneration.from_pretrained("/root/autodl-tmp/flan-t5-large")

    # Load the tokenizer
    tokenizer_se = T5Tokenizer.from_pretrained("/root/autodl-tmp/flan-t5-large")

    # Create the pipeline
    se_generator = pipeline("text2text-generation", model=model_se, tokenizer=tokenizer_se,
        top_k=50,
        truncation=True,
        batch_size=256,
        device=0 if int(os.environ.get("LOCAL_RANK", 0)) == 0 else -1,)
    #############################e


    






    
    #########################b

    ds = load_dataset("json", data_files="/root/autodl-tmp/BIG-Bench-Hard/bbh/navigate.json",field="examples")['train']
    ds_split=ds.train_test_split(test_size=0.2)
    prompt_all=ds['input']
    prompt_all_new= [prompt.replace('\n', ' ') for prompt in prompt_all]
    answer_all=ds['target']
    prompt_train=ds_split['train']['input']
    prompt_train=[]
    prompt_test=ds_split['test']['input']
    prompt_train
    

    ##########################e


    trlx.train(
        prompts=prompt_train,
        eval_prompts=prompt_test,
        reward_fn=reward_se,
        metric_fn=metric_se,
        config=config,
    )

    

    
    
if __name__ == "__main__":
    hparams = {} if len(sys.argv) == 1 else json.loads(sys.argv[1])
    main(hparams)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:201                                                                                  │
# │                                                                                                  │
# │   198                                                                                            │
# │   199                                                                                            │
# │   200 if __name__ == "__main__":                                                                 │
# │ ❱ 201 │   hparams = {} if len(sys.argv) == 1 else json.loads(sys.argv[1])                        │
# │   202 │   main(hparams)                                                                          │
# │   203                                                                                            │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/json/__init__.py:357 in loads                                     │
# │                                                                                                  │
# │   354 │   if (cls is None and object_hook is None and                                            │
# │   355 │   │   │   parse_int is None and parse_float is None and                                  │
# │   356 │   │   │   parse_constant is None and object_pairs_hook is None and not kw):              │
# │ ❱ 357 │   │   return _default_decoder.decode(s)                                                  │
# │   358 │   if cls is None:                                                                        │
# │   359 │   │   cls = JSONDecoder                                                                  │
# │   360 │   if object_hook is not None:                                                            │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/json/decoder.py:337 in decode                                     │
# │                                                                                                  │
# │   334 │   │   containing a JSON document).                                                       │
# │   335 │   │                                                                                      │
# │   336 │   │   """                                                                                │
# │ ❱ 337 │   │   obj, end = self.raw_decode(s, idx=_w(s, 0).end())                                  │
# │   338 │   │   end = _w(s, end).end()                                                             │
# │   339 │   │   if end != len(s):                                                                  │
# │   340 │   │   │   raise JSONDecodeError("Extra data", s, end)                                    │
# │                                                                                                  │
# │ /root/miniconda3/lib/python3.8/json/decoder.py:355 in raw_decode                                 │
# │                                                                                                  │
# │   352 │   │   try:                                                                               │
# │   353 │   │   │   obj, end = self.scan_once(s, idx)                                              │
# │   354 │   │   except StopIteration as err:                                                       │
# │ ❱ 355 │   │   │   raise JSONDecodeError("Expecting value", s, err.value) from None               │
# │   356 │   │   return obj, end                                                                    │
# │   357                                                                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
def reward_se( prompts: List[str], outputs: List[str]) -> List[float]:
    rewards = []
    for q, a in zip(prompts, outputs):
        feedback_prompt = f'Is the answer to the question correct? The question is: {q}. The answer is: {a}'
        feedback = se_generator(feedback_prompt)[0]['generated_text']  # Assuming 'model' is your trained T5 model
        feedback = feedback.lower().strip()
        print(feedback)
        reward = 1.0 if 'yes' in feedback else 0.0
        
        rewards.append(reward)
    return rewards

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration, pipeline
    
    # Load the model
model_se_0 = T5ForConditionalGeneration.from_pretrained("/root/autodl-tmp/flan-t5-large")

    # Load the tokenizer
tokenizer_se = T5Tokenizer.from_pretrained("/root/autodl-tmp/flan-t5-large")

    # Create the pipeline
se_generator= pipeline("text2text-generation", model=model_se_0, tokenizer=tokenizer_se,
                        do_sample= False,
                        top_k= 50,
                        top_p= 0.95,
                        max_length=256,
                        eos_token_id= tokenizer_se.eos_token_id,
                        temperature= 1.0,

                          device=0 if int(os.environ.get("LOCAL_RANK", 0)) == 0 else -1,)



"""    
    # Load the model
model_se_1 = T5ForConditionalGeneration.from_pretrained("/root/autodl-tmp/msc_ml/t5_large_checkpoints/checkpoint_94")

    # Create the pipeline
se_generator_1 = pipeline("text2text-generation", model=model_se_1, tokenizer=tokenizer_se,

        device=0 if int(os.environ.get("LOCAL_RANK", 0)) == 0 else -1,)
"""
# Out:
# '    \n    # Load the model\nmodel_se_1 = T5ForConditionalGeneration.from_pretrained("/root/autodl-tmp/msc_ml/t5_large_checkpoints/checkpoint_94")\n\n    # Create the pipeline\nse_generator_1 = pipeline("text2text-generation", model=model_se_1, tokenizer=tokenizer_se,\n\n        device=0 if int(os.environ.get("LOCAL_RANK", 0)) == 0 else -1,)\n'

# %%
ds = load_dataset("json", data_files="/root/autodl-tmp/BIG-Bench-Hard/bbh/logical_deduction_three_objects.json",field="examples")['train']
ds_split=ds.train_test_split(test_size=0.2)
prompt_all=ds['input']
prompt_all_new= [prompt.replace('\n', ' ') for prompt in prompt_all]
answer_all=ds['target']
prompt_train=ds_split['train']['input']
prompt_test=ds_split['test']['input']
answer_test=ds_split['test']['target']
answer_train=ds_split['train']['target']



prompt_test_new= ['[{}] Let’ s think step by step.'.format(prompt.replace('\n', ' ')) for prompt in prompt_test]
prompt_train_new= ['[{}] Let’ s think step by step.'.format(prompt.replace('\n', ' ')) for prompt in prompt_train]
    

    
    

def accuracy(if_multi:bool ,prompts: List[str], outputs: List[str]) -> Dict[str, List[float]]:
    match=[]
    
    if if_multi==True:
        
        for i,prompt in enumerate(prompts):
            index = prompt_all_new.index(prompt)
            output_valid=""
            valid_letters = re.search(r'the answer:.*(\([A-Za-z]\))', outputs[i], re.IGNORECASE)
            if match:
                output_valid = valid_letters.group(1)  # The first group is the letter inside the parentheses
            if output_valid.lower().strip()==answer_all[index].lower().strip():
                is_correct=1.0
            else:
                is_correct=0.0
                
            match.append(is_correct)
            
            
    else:
        
        for i,prompt in enumerate(prompts):
            index = prompt_all_new.index(prompt)
            if outputs[i].lower().strip()==answer_all[index].lower().strip():
                is_correct=1.0
            else:
                is_correct=0.0

            match.append(is_correct)

    return sum(match)/len(match)
# Out:
# Found cached dataset json (/root/.cache/huggingface/datasets/json/default-fba734bb4c8b83f9/0.0.0/e347ab1c932092252e717ff3f949105a4dd28b27e842dd53157d2f72e276c2e4)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
outputs_0=[]

for i in range(len(prompt_test_new)):
    
    question=prompt_test_new[i]
    answer=answer_test[i]
    print('££££££££££££££££££££££££££',question)
    generation=se_generator(question)[0]['generated_text']
    outputs_0.append(generation)
    print('$$$$$$$$$$$$$',generation)
    print('============',answer)
    print(reward_se(prompts=[question], outputs=[generation]))
# Out:
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. A fruit stand sells three fruits: kiwis, loquats, and cantaloupes. The kiwis are less expensive than the loquats. The cantaloupes are less expensive than the kiwis. Options: (A) The kiwis are the cheapest (B) The loquats are the cheapest (C) The cantaloupes are the cheapest] Let’ s think step by step.
# $$$$$$$$$$$$$ The kiwis are cheaper than the loquats. The cantaloupes are cheaper than the kiwis. The cheapest answer: (C).
# ============ (C)
# the kiwis are cheaper than the loquats. the cantaloupes are cheaper than the kiwis. the cheapest
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a branch, there are three birds: an owl, a crow, and a cardinal. The crow is to the left of the owl. The owl is the second from the left. Options: (A) The owl is the rightmost (B) The crow is the rightmost (C) The cardinal is the rightmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The cardinal is the rightmost because it is the second from the left. The answer: (C).
# ============ (C)
# the cardinal is the rightmost because it is the second from the left. the answer: (c).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. A fruit stand sells three fruits: apples, peaches, and mangoes. The mangoes are less expensive than the peaches. The apples are less expensive than the mangoes. Options: (A) The apples are the second-most expensive (B) The peaches are the second-most expensive (C) The mangoes are the second-most expensive] Let’ s think step by step.
# $$$$$$$$$$$$$ The apples are the second-most expensive because they are less expensive than the mangoes. The answer: (A).
# ============ (C)
# the apples are the second-most expensive because they are less expensive than the mangoes. the answer: (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In an antique car show, there are three vehicles: a tractor, a station wagon, and a limousine. The tractor is newer than the limousine. The station wagon is the newest. Options: (A) The tractor is the newest (B) The station wagon is the newest (C) The limousine is the newest] Let’ s think step by step.
# $$$$$$$$$$$$$ The station wagon is the newest because it is the newest vehicle. The answer: (B).
# ============ (B)
# the station wagon is the newest because it is the newest vehicle. so, the answer is (b).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a shelf, there are three books: a yellow book, a brown book, and a red book. The red book is to the left of the brown book. The yellow book is to the right of the brown book. Options: (A) The yellow book is the leftmost (B) The brown book is the leftmost (C) The red book is the leftmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The red book is to the left of the brown book. The yellow book is to the right of the brown book. The brown book is the leftmost. The answer: (B).
# ============ (C)
# the red book is to the left of the brown book. the yellow book is to the right of the brown book. the brown book is the leftmost. the answer: (b).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a shelf, there are three books: a green book, a brown book, and an orange book. The brown book is to the left of the orange book. The green book is to the left of the brown book. Options: (A) The green book is the second from the left (B) The brown book is the second from the left (C) The orange book is the second from the left] Let’ s think step by step.
# $$$$$$$$$$$$$ The orange book is the second from the left. The brown book is to the left of the orange book. The green book is to the left of the brown book. The green book is the second from the left. So, the answer is (C).
# ============ (B)
# the orange book is the second from the left. the brown book is to the left of the orange book. the green book is to the left of the brown book. the green book is the second from the left. so, the answer is (c).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. A fruit stand sells three fruits: loquats, mangoes, and apples. The mangoes are more expensive than the apples. The loquats are more expensive than the mangoes. Options: (A) The loquats are the most expensive (B) The mangoes are the most expensive (C) The apples are the most expensive] Let’ s think step by step.
# $$$$$$$$$$$$$ The loquats are more expensive than the mangoes. The loquats are the most expensive. The answer: (A).
# ============ (A)
# the loquats are more expensive than the mangoes. the loquats are the most expensive. the answer: (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a branch, there are three birds: a blue jay, a quail, and a falcon. The falcon is to the right of the blue jay. The blue jay is to the right of the quail. Options: (A) The blue jay is the leftmost (B) The quail is the leftmost (C) The falcon is the leftmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The blue jay is to the right of the quail. The falcon is to the right of the blue jay. The blue jay is to the right of the quail. The blue jay is the leftmost. So, the answer is (A).
# ============ (B)
# yes
# [1.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a branch, there are three birds: a quail, an owl, and a hummingbird. The quail is to the left of the owl. The owl is to the left of the hummingbird. Options: (A) The quail is the second from the left (B) The owl is the second from the left (C) The hummingbird is the second from the left] Let’ s think step by step.
# $$$$$$$$$$$$$ The quail is to the left of the owl. The owl is to the left of the hummingbird. The quail is to the left of the owl. The answer: (B).
# ============ (B)
# the quail is to the left of the owl. the owl is to the left of the hummingbird. the quail is to the left of the owl. the answer: (b).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In a golf tournament, there were three golfers: Ana, Rob, and Joe. Joe finished above Ana. Rob finished above Joe. Options: (A) Ana finished last (B) Rob finished last (C) Joe finished last] Let’ s think step by step.
# $$$$$$$$$$$$$ Joe finished last because he finished before Ana. The answer: (A).
# ============ (A)
# ana finished last because she finished before joe. the answer: (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In an antique car show, there are three vehicles: a station wagon, a minivan, and a truck. The minivan is newer than the truck. The station wagon is newer than the minivan. Options: (A) The station wagon is the oldest (B) The minivan is the oldest (C) The truck is the oldest] Let’ s think step by step.
# $$$$$$$$$$$$$ The station wagon is older than the minivan. The station wagon is older than the minivan. The station wagon is the oldest. So, the answer is (A).
# ============ (C)
# the station wagon is older than the minivan. the station wagon is older than the minivan. the station wagon is the oldest. so, the answer is (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a shelf, there are three books: a blue book, an orange book, and a red book. The blue book is the rightmost. The orange book is the leftmost. Options: (A) The blue book is the leftmost (B) The orange book is the leftmost (C) The red book is the leftmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The red book is the leftmost because it is the only book that is left. The answer: (C).
# ============ (B)
# the red book is the only book that is left. so, the answer is (c).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In an antique car show, there are three vehicles: a convertible, a limousine, and a bus. The limousine is older than the bus. The bus is older than the convertible. Options: (A) The convertible is the second-newest (B) The limousine is the second-newest (C) The bus is the second-newest] Let’ s think step by step.
# $$$$$$$$$$$$$ The bus is older than the convertible. The bus is older than the convertible. The bus is the second-newest. So, the answer is (C).
# ============ (C)
# the bus is the second-newest. the bus is older than the convertible. the bus is older than the convertible. the bus is the second-newest. so, the answer is (c).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. A fruit stand sells three fruits: loquats, mangoes, and apples. The mangoes are more expensive than the apples. The loquats are more expensive than the mangoes. Options: (A) The loquats are the second-most expensive (B) The mangoes are the second-most expensive (C) The apples are the second-most expensive] Let’ s think step by step.
# $$$$$$$$$$$$$ The loquats are second most expensive than the mangoes. The answer: (A).
# ============ (B)
# the loquats are second most expensive than the mangoes. the answer: (b).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a branch, there are three birds: a crow, a falcon, and a hummingbird. The crow is to the left of the falcon. The hummingbird is to the left of the crow. Options: (A) The crow is the second from the left (B) The falcon is the second from the left (C) The hummingbird is the second from the left] Let’ s think step by step.
# $$$$$$$$$$$$$ The crow is to the left of the falcon. The hummingbird is to the left of the crow. The answer: (A).
# ============ (A)
# the crow is to the left of the falcon. the hummingbird is to the left of the crow. the answer: (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. A fruit stand sells three fruits: apples, peaches, and mangoes. The mangoes are less expensive than the peaches. The apples are less expensive than the mangoes. Options: (A) The apples are the cheapest (B) The peaches are the cheapest (C) The mangoes are the cheapest] Let’ s think step by step.
# $$$$$$$$$$$$$ The apples are less expensive than the mangoes. The apples are cheaper than the mangoes. The cheapest answer: (C).
# ============ (A)
# the apples are cheaper than the mangoes. the cheapest
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. A fruit stand sells three fruits: plums, apples, and loquats. The loquats are the cheapest. The plums are less expensive than the apples. Options: (A) The plums are the cheapest (B) The apples are the cheapest (C) The loquats are the cheapest] Let’ s think step by step.
# $$$$$$$$$$$$$ The plums are less expensive than the apples. The plums are the cheapest. The answer: (A).
# ============ (C)
# the plums are the cheapest. the plums are the cheapest. the answer: (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In an antique car show, there are three vehicles: a hatchback, a convertible, and a tractor. The convertible is older than the tractor. The hatchback is the second-newest. Options: (A) The hatchback is the second-newest (B) The convertible is the second-newest (C) The tractor is the second-newest] Let’ s think step by step.
# $$$$$$$$$$$$$ The hatchback is the second-newest because it is the second-newest vehicle. The answer: (A).
# ============ (A)
# the hatchback is the second-newest because it is the second-newest vehicle. the answer: (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. A fruit stand sells three fruits: apples, pears, and loquats. The pears are more expensive than the loquats. The pears are less expensive than the apples. Options: (A) The apples are the cheapest (B) The pears are the cheapest (C) The loquats are the cheapest] Let’ s think step by step.
# $$$$$$$$$$$$$ The apples are the cheapest because they are the most expensive. The loquats are the cheapest because they are the cheapest. So, the answer is (C).
# ============ (C)
# the loquats are the cheapest because they are the cheapest. so, the answer is (c).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a shelf, there are three books: an orange book, a yellow book, and a blue book. The blue book is to the right of the yellow book. The orange book is the second from the left. Options: (A) The orange book is the rightmost (B) The yellow book is the rightmost (C) The blue book is the rightmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The blue book is to the right of the yellow book. The orange book is the second from the left. The orange book is the rightmost. So, the answer is (A).
# ============ (C)
# the orange book is the rightmost
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a shelf, there are three books: a purple book, a black book, and a blue book. The purple book is to the right of the blue book. The black book is the second from the left. Options: (A) The purple book is the rightmost (B) The black book is the rightmost (C) The blue book is the rightmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The black book is second from the left. The black book is the rightmost. The answer: (B).
# ============ (A)
# the black book is the rightmost
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. A fruit stand sells three fruits: apples, peaches, and loquats. The loquats are less expensive than the apples. The peaches are more expensive than the apples. Options: (A) The apples are the cheapest (B) The peaches are the cheapest (C) The loquats are the cheapest] Let’ s think step by step.
# $$$$$$$$$$$$$ The loquats are cheaper than the apples. The loquats are the cheapest. The answer: (C).
# ============ (C)
# the loquats are cheaper than the apples. the loquats are the cheapest. the answer: (c).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a shelf, there are three books: a gray book, a purple book, and a red book. The purple book is to the left of the red book. The gray book is to the left of the purple book. Options: (A) The gray book is the rightmost (B) The purple book is the rightmost (C) The red book is the rightmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The red book is to the right of the purple book. The gray book is to the left of the purple book. The gray book is the rightmost. So, the answer is (A).
# ============ (C)
# the gray book is the rightmost
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. A fruit stand sells three fruits: apples, peaches, and loquats. The loquats are less expensive than the apples. The peaches are more expensive than the apples. Options: (A) The apples are the most expensive (B) The peaches are the most expensive (C) The loquats are the most expensive] Let’ s think step by step.
# $$$$$$$$$$$$$ The loquats are less expensive than the apples. The peaches are more expensive than the apples. The answer: (A).
# ============ (B)
# the loquats are less expensive than the apples. the peaches are more expensive than the apples. the answer: (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a shelf, there are three books: a red book, a gray book, and a white book. The white book is to the left of the gray book. The red book is the second from the left. Options: (A) The red book is the second from the left (B) The gray book is the second from the left (C) The white book is the second from the left] Let’ s think step by step.
# $$$$$$$$$$$$$ The red book is the second from the left. The answer: (A).
# ============ (A)
# the red book is the second from the left. so the final answer is (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In an antique car show, there are three vehicles: a sedan, a tractor, and a bus. The sedan is older than the tractor. The bus is older than the sedan. Options: (A) The sedan is the second-newest (B) The tractor is the second-newest (C) The bus is the second-newest] Let’ s think step by step.
# $$$$$$$$$$$$$ The bus is older than the sedan. The bus is older than the sedan. The bus is the second-newest. So, the answer is (C).
# ============ (A)
# the bus is the second-newest because it is older than the sedan. the answer: (c).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a branch, there are three birds: a robin, a blue jay, and a crow. The robin is to the right of the crow. The robin is to the left of the blue jay. Options: (A) The robin is the leftmost (B) The blue jay is the leftmost (C) The crow is the leftmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The robin is to the left of the blue jay. The robin is to the left of the blue jay. The robin is to the leftmost. So, the answer is (A).
# ============ (C)
# the robin is to the leftmost. the robin is to the leftmost. the robin is to the leftmost. so, the answer is (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In a golf tournament, there were three golfers: Rob, Mel, and Joe. Joe finished below Mel. Rob finished below Joe. Options: (A) Rob finished last (B) Mel finished last (C) Joe finished last] Let’ s think step by step.
# $$$$$$$$$$$$$ Mel finished last because Mel finished below Joe. Joe finished last because Joe finished below Mel. The answer: (B).
# ============ (A)
# mel finished last because mel finished below joe. joe finished last because joe finished below mel. the answer: (b).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In an antique car show, there are three vehicles: a sedan, a convertible, and a truck. The truck is the newest. The sedan is older than the convertible. Options: (A) The sedan is the oldest (B) The convertible is the oldest (C) The truck is the oldest] Let’ s think step by step.
# $$$$$$$$$$$$$ The sedan is older than the convertible. So the sedan is the oldest. The answer: (A).
# ============ (A)
# the sedan is older than the convertible. so the sedan is the oldest. the final answer: (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a shelf, there are three books: a red book, a blue book, and an orange book. The red book is to the left of the orange book. The orange book is the second from the left. Options: (A) The red book is the leftmost (B) The blue book is the leftmost (C) The orange book is the leftmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The red book is to the left of the orange book. The orange book is the second from the left. The orange book is the leftmost. So, the answer is (C).
# ============ (A)
# the orange book is the leftmost
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In a golf tournament, there were three golfers: Ana, Mel, and Ada. Ada finished above Ana. Mel finished below Ana. Options: (A) Ana finished second (B) Mel finished second (C) Ada finished second] Let’ s think step by step.
# $$$$$$$$$$$$$ Mel finished below Ana. Mel finished above Ada. Mel finished second. The answer: (B).
# ============ (A)
# mel finished below ana. mel finished above ada. mel finished second. the answer: (b).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a branch, there are three birds: a blue jay, a falcon, and a hummingbird. The blue jay is to the right of the falcon. The hummingbird is to the left of the falcon. Options: (A) The blue jay is the second from the left (B) The falcon is the second from the left (C) The hummingbird is the second from the left] Let’ s think step by step.
# $$$$$$$$$$$$$ The hummingbird is to the left of the falcon. The hummingbird is to the right of the blue jay. The answer: (A).
# ============ (B)
# the falcon is the second from the left. the hummingbird is to the left of the falcon. the answer: (b).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. A fruit stand sells three fruits: oranges, mangoes, and plums. The plums are less expensive than the mangoes. The oranges are less expensive than the plums. Options: (A) The oranges are the second-most expensive (B) The mangoes are the second-most expensive (C) The plums are the second-most expensive] Let’ s think step by step.
# $$$$$$$$$$$$$ The oranges are the second-most expensive fruit because they are less expensive than the plums. The answer: (A).
# ============ (C)
# the plums are the second-most expensive fruit because they are less expensive than the oranges. the answer: (c).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. A fruit stand sells three fruits: apples, pears, and loquats. The pears are more expensive than the loquats. The pears are less expensive than the apples. Options: (A) The apples are the second-most expensive (B) The pears are the second-most expensive (C) The loquats are the second-most expensive] Let’ s think step by step.
# $$$$$$$$$$$$$ The apples are the second-most expensive. The pears are less expensive than the apples. The answer: (A).
# ============ (B)
# the apples are the second-most expensive. the pears are less expensive than the apples. the answer: (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In a golf tournament, there were three golfers: Amy, Ana, and Joe. Amy finished below Ana. Ana finished below Joe. Options: (A) Amy finished last (B) Ana finished last (C) Joe finished last] Let’ s think step by step.
# $$$$$$$$$$$$$ Amy finished below Ana. Ana finished below Joe. Joe finished last. So, the answer is (C).
# ============ (A)
# joe finished last because amy finished below ana. so, the answer is (c).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a branch, there are three birds: a raven, a quail, and a crow. The quail is the leftmost. The raven is the rightmost. Options: (A) The raven is the leftmost (B) The quail is the leftmost (C) The crow is the leftmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The quail is the leftmost. The raven is the rightmost. The answer: (A).
# ============ (B)
# the quail is the leftmost. the raven is the rightmost. the answer: (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. A fruit stand sells three fruits: cantaloupes, oranges, and watermelons. The oranges are the most expensive. The cantaloupes are more expensive than the watermelons. Options: (A) The cantaloupes are the second-most expensive (B) The oranges are the second-most expensive (C) The watermelons are the second-most expensive] Let’ s think step by step.
# $$$$$$$$$$$$$ The cantaloupes are second most expensive than the watermelons because they are cheaper than the oranges. The answer: (A).
# ============ (A)
# the cantaloupes are second most expensive than the watermelons because they are cheaper than the oranges. the answer: (c).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In a golf tournament, there were three golfers: Ana, Dan, and Mel. Dan finished second. Mel finished first. Options: (A) Ana finished second (B) Dan finished second (C) Mel finished second] Let’ s think step by step.
# $$$$$$$$$$$$$ Dan finished second because he was the last golfer to finish. The answer: (B).
# ============ (B)
# dan finished second because he was the last golfer to finish. the answer: (b).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In an antique car show, there are three vehicles: a minivan, a bus, and a sedan. The minivan is newer than the sedan. The minivan is older than the bus. Options: (A) The minivan is the oldest (B) The bus is the oldest (C) The sedan is the oldest] Let’ s think step by step.
# $$$$$$$$$$$$$ The minivan is older than the bus. The bus is the oldest. The answer: (B).
# ============ (C)
# the bus is the oldest. the bus is the oldest. the answer: (b).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a branch, there are three birds: a hawk, a cardinal, and a falcon. The hawk is to the left of the cardinal. The hawk is the second from the left. Options: (A) The hawk is the rightmost (B) The cardinal is the rightmost (C) The falcon is the rightmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The cardinal is the rightmost because it is to the left of the hawk. The hawk is the second from the left. The cardinal is the rightmost because it is to the right of the hawk. The answer: (B).
# ============ (B)
# no
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In a golf tournament, there were three golfers: Ana, Rob, and Joe. Joe finished above Ana. Rob finished above Joe. Options: (A) Ana finished second (B) Rob finished second (C) Joe finished second] Let’ s think step by step.
# $$$$$$$$$$$$$ Joe finished second to Rob because Joe finished first to the hole. The answer: (A).
# ============ (C)
# ana finished second
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a branch, there are three birds: an owl, a crow, and a cardinal. The crow is to the left of the owl. The owl is the second from the left. Options: (A) The owl is the second from the left (B) The crow is the second from the left (C) The cardinal is the second from the left] Let’ s think step by step.
# $$$$$$$$$$$$$ The owl is the second from the left. So the answer is (A).
# ============ (A)
# the owl is the second from the left. so the answer is (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. A fruit stand sells three fruits: loquats, watermelons, and cantaloupes. The watermelons are the second-most expensive. The loquats are more expensive than the cantaloupes. Options: (A) The loquats are the second-most expensive (B) The watermelons are the second-most expensive (C) The cantaloupes are the second-most expensive] Let’ s think step by step.
# $$$$$$$$$$$$$ The loquats are more expensive than the cantaloupes. The loquats are second most expensive. The answer: (A).
# ============ (B)
# the loquats are the second-most expensive. the loquats are the second-most expensive. the answer: (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a shelf, there are three books: a purple book, a black book, and a blue book. The purple book is to the right of the blue book. The black book is the second from the left. Options: (A) The purple book is the leftmost (B) The black book is the leftmost (C) The blue book is the leftmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The black book is second from the left. The blue book is the leftmost. The answer: (C).
# ============ (C)
# the blue book is the leftmost. the answer: (c).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In an antique car show, there are three vehicles: a motorcyle, a bus, and a tractor. The motorcyle is the oldest. The bus is newer than the tractor. Options: (A) The motorcyle is the newest (B) The bus is the newest (C) The tractor is the newest] Let’ s think step by step.
# $$$$$$$$$$$$$ The bus is newer than the tractor. The bus is the newest. The answer: (B).
# ============ (B)
# the bus is the newest. the bus is the newest. the answer: (b).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In an antique car show, there are three vehicles: a motorcyle, a limousine, and a convertible. The motorcyle is newer than the limousine. The convertible is newer than the motorcyle. Options: (A) The motorcyle is the newest (B) The limousine is the newest (C) The convertible is the newest] Let’ s think step by step.
# $$$$$$$$$$$$$ The convertible is newer than the motorcyle. The answer: (C).
# ============ (C)
# the convertible is newer than the motorcyle. so the final answer is (c).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a branch, there are three birds: a hummingbird, a quail, and a crow. The crow is the second from the left. The hummingbird is to the left of the crow. Options: (A) The hummingbird is the leftmost (B) The quail is the leftmost (C) The crow is the leftmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The hummingbird is to the left of the crow. The hummingbird is to the left of the crow. The answer: (A).
# ============ (A)
# the hummingbird is to the left of the crow. the hummingbird is to the left of the crow. the answer: (a).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a branch, there are three birds: a quail, an owl, and a hummingbird. The quail is to the left of the owl. The owl is to the left of the hummingbird. Options: (A) The quail is the leftmost (B) The owl is the leftmost (C) The hummingbird is the leftmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The quail is to the left of the owl. The owl is to the left of the hummingbird. The quail is to the left of the owl. The answer: (B).
# ============ (A)
# the quail is to the left of the owl. the owl is to the left of the hummingbird. the quail is to the left of the owl. the answer: (b).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. On a shelf, there are three books: an orange book, a white book, and a purple book. The orange book is to the left of the white book. The purple book is the rightmost. Options: (A) The orange book is the rightmost (B) The white book is the rightmost (C) The purple book is the rightmost] Let’ s think step by step.
# $$$$$$$$$$$$$ The white book is the rightmost because it is the first book on the shelf. The answer: (B).
# ============ (C)
# the white book is the rightmost because it is the first book on the shelf. the answer: (b).
# [0.0]
# ££££££££££££££££££££££££££ [The following paragraphs each describe a set of three objects arranged in a fixed order. The statements are logically consistent within each paragraph. In a golf tournament, there were three golfers: Ana, Mel, and Ada. Ada finished above Ana. Mel finished below Ana. Options: (A) Ana finished first (B) Mel finished first (C) Ada finished first] Let’ s think step by step.
# $$$$$$$$$$$$$ Mel finished below Ana. Mel finished above Ada. Mel finished first. The answer: (B).
# ============ (C)
# mel finished below ana. mel finished above ada. mel finished first. the answer: (b).
# [0.0]

# %%
import torch

# Your code that uses CUDA memory

# Empty the CUDA memory
torch.cuda.empty_cache()

# %%
outputs_0=[]
for i in range(len(prompt_train)):
    
    question=prompt_train[i]
    answer=answer_train[i]
    #print('££££££££££££££££££££££££££',question)
    generation=se_generator_0(question)[0]['generated_text']
    outputs_0.append(generation)
    #print('$$$$$$$$$$$$$',generation)
    #print('============',answer)
    #print(reward_fn(prompts=[question], outputs=[generation]))
    
outputs_1=[]
for i in range(len(prompt_train)):
    
    question=prompt_train[i]
    answer=answer_train[i]
    #print('££££££££££££££££££££££££££',question)
    generation=se_generator_1(question)[0]['generated_text']
    outputs_1.append(generation)
    #print('$$$$$$$$$$$$$',generation)
    #print('============',answer)
    #print(reward_fn(prompts=[question], outputs=[generation]))
    
accuracy_0=accuracy(prompt_train_new,outputs_0)
print(accuracy_0)
accuracy_1=accuracy(prompt_train_new,outputs_1)
print(accuracy_1)

# %%
s = 'THE Answer:: is here: (C)'
match = re.search(r'the answer.*(\([A-Za-z]\))', s, re.IGNORECASE)
if match:
    answer = match.group(1)  # The first group is the letter inside the parentheses
    print(answer)
# Out:
# (C)
